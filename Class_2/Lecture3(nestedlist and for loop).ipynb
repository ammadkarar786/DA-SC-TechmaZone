# %% [markdown]
# ### Task 1: HR Employee List Check
#
# **Scenario:** You work in Human Resources (HR). You have a list of employees. Some employees have bonus information, but some do not. You need to get information from the list safely.
#
# **The Data:**
# ```python
# # Format: [ID, Name, Department, Salary, (Optional) Bonus]
# employees = [
#     ["E001", "Sarah Jenkins", "Finance", 85000, [2021, 2023]],
#     ["E002", "Michael Chen", "Engineering", 92000],
#     ["E003", "Priya Patel", "Marketing", 78000, [2022]],
#     ["E004", "David Ross", "Sales", 81000]
# ]
# ```
#
# **Instructions:**
# 1.  Print the **Department** of the second employee (index 1). Use double indexing (e.g., `list[1][2]`).
# 2.  Print the **last employee** in the list. Use negative indexing (e.g., `list[-1]`).
#
# ---

# %% [markdown]
# ### Task 2: Finance Audit Sample
# **Scenario:** You are a finance auditor. You have a list of daily money logs. The manager wants to check only every **5th day** to save time. You need to make a new list with these specific days.
#
# **The Data:**
# ```python
# # Format: [Day Name, Amount]
# daily_logs = [
#     ["Day 01", 1200], ["Day 02", 1250], ["Day 03", 1180], ["Day 04", 1300],
#     ["Day 05", 1320], ["Day 06", 1350], ["Day 07", 1290], ["Day 08", 1400],
#     ["Day 09", 1410], ["Day 10", 1450], ["Day 11", 1380], ["Day 12", 1500],
#     ["Day 13", 1520], ["Day 14", 1580], ["Day 15", 1490], ["Day 16", 1600],
#     ["Day 17", 1620], ["Day 18", 1650], ["Day 19", 1590], ["Day 20", 1700]
# ]
# ```
#
# **Instructions:**
# 1.  Create an empty list called `audit_sample`.
# 2.  Use a `for` loop with the `range()` function.
#     *   Start at index `4` (Day 05).
#     *   Step by `5` (to get every 5th item).
# 3.  Add the selected items to `audit_sample`.
#
# ---

# %% [markdown]
# ### Task 3: Warehouse Stock Report
# **Scenario:** You manage a warehouse. You have a list of products and their stock levels. You need to find items that have low stock and need more orders.
#
# **The Data:**
# ```python
# # Format: [SKU, Product Name, Current Stock, Minimum Stock Needed]
# inventory = [
#     ["SKU-101", "Industrial Drill", 45, 50],
#     ["SKU-102", "Safety Goggles", 120, 30],
#     ["SKU-103", "Steel Bolts", 15, 20],
#     ["SKU-104", "Work Gloves", 8, 25],
#     ["SKU-105", "Hard Hat", 60, 40]
# ]
# ```
#
# **Instructions:**
# 1.  Create an empty list called `restock_order`.
# 2.  Use a `for` loop with `range(len(inventory))` to go through the list.
# 3.  After the loop, print: `"Total items to order: [count]"`.
#
# ---
#
# ### Task 4: Client Fee Calculation
# **Scenario:** You work with client money plans. You need to calculate fees for each client. Your manager wants you to use direct iteration because it is cleaner and easier to read.
#
# **The Data:**
# ```python
# # Format: [Client ID, Asset Type, Value, Fee Percentage]
# clients = [
#     ["C-500", "Equities", 500000, 1.2],
#     ["C-501", "Bonds", 320000, 0.8],
#     ["C-502", "Real Estate", 750000, 1.5],
#     ["C-503", "Commodities", 120000, 1.0]
# ]
# ```
#
# **Instructions:**
# 1.  Use a direct loop: `for client_id, asset, value, fee in clients:`. Do not use index numbers like `[0]` or `[1]`.
# 2.  Calculate the fee: `value * (fee / 100)`.
# 3.  Save the result in a new list: `[Client ID, Final Fee]`.
# 4.  Show the final list.
#
# ---

# %% [markdown]
# ### Task 5: Regional Sales Summary
# **Scenario:** You need to make a sales report. You have different regions. Each region has different sales people. You need to calculate the total sales for the whole company and find top workers.
#
# **The Data:**
# ```python
# # Outer List = Regions, Inner List = Sales People
# # Format: [Name, Q1, Q2, Q3, Q4]
# regional_sales = [
#     # North
#     [["John Doe", 12000, 13000, 12500, 14000], ["Jane Smith", 11000, 11500, 12000, 11800]],
#     # South
#     [["Bob White", 9000, 9500, 9200, 9800], ["Alice Green", 10500, 10800, 11200, 11500]],
#     # West
#     [["Diana Prince", 15000, 16000, 15500, 17000]]
# ]
# ```
#
# **Instructions:**
# 1.  Create a variable `total_sales = 0`.
# 2.  Use a loop to go through each **region**.
# 3.  Inside that loop, use another loop to go through each **person** in the region.
# 4.  For each person:
#     *   Add their sales (Q1 to Q4) to `total_sales`.
# 5.  At the end, print the `total_sales`.
