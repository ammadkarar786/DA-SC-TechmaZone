# %%
print("Hello")
# Out:
# Hello

# %%
import csv

Dataset = open('sales_data.csv')
# Dataset = list(csv.reader(Dataset))
list(csv.reader(Dataset))
# Out:
# [['TransactionID',
#   'Product',
#   'Quantity',
#   'UnitPrice',
#   'Status',
#   'CustomerRegion'],
#  ['T0001', 'Charger', '3', '1083.45', 'Completed', 'West'],
#  ['T0002', 'Charger', '2', '992.66', 'Cancelled', 'North'],
#  ['T0003', 'Webcam', '3', '1144.62', 'Pending', 'South'],
#  ['T0004', 'Mouse', '8', '43.76', 'Pending', 'International'],
#  ['T0005', 'Mouse', '2', '660.89', 'Pending', 'South'],
#  ['T0006', 'Mouse', '8', '242.69', 'Completed', 'South'],
#  ['T0007', 'Keyboard', '3', '507.11', 'Cancelled', 'International'],
#  ['T0008', 'Charger', '9', '91.60', 'Completed', 'North'],
#  ['T0009', 'Monitor', '8', '236.28', 'Completed', 'South'],
#  ['T0010', 'Laptop', '2', '304.67', 'Pending', 'International'],
#  ['T0011', 'Monitor', '7', '149.32', 'Cancelled', 'East'],
#  ['T0012', 'Charger', '3', '603.68', 'Refunded', 'South'],
#  ['T0013', 'Webcam', '3', '34.13', 'Pending', 'North'],
#  ['T0014', 'USB Drive', '10', '1159.06', 'Refunded', 'International'],
# ...

# %%
Clean_Dataset = Dataset[1:]

# %%
Clean_Dataset
# Out:
# [['T0001', 'Charger', '3', '1083.45', 'Completed', 'West'],
#  ['T0002', 'Charger', '2', '992.66', 'Cancelled', 'North'],
#  ['T0003', 'Webcam', '3', '1144.62', 'Pending', 'South'],
#  ['T0004', 'Mouse', '8', '43.76', 'Pending', 'International'],
#  ['T0005', 'Mouse', '2', '660.89', 'Pending', 'South'],
#  ['T0006', 'Mouse', '8', '242.69', 'Completed', 'South'],
#  ['T0007', 'Keyboard', '3', '507.11', 'Cancelled', 'International'],
#  ['T0008', 'Charger', '9', '91.60', 'Completed', 'North'],
#  ['T0009', 'Monitor', '8', '236.28', 'Completed', 'South'],
#  ['T0010', 'Laptop', '2', '304.67', 'Pending', 'International'],
#  ['T0011', 'Monitor', '7', '149.32', 'Cancelled', 'East'],
#  ['T0012', 'Charger', '3', '603.68', 'Refunded', 'South'],
#  ['T0013', 'Webcam', '3', '34.13', 'Pending', 'North'],
#  ['T0014', 'USB Drive', '10', '1159.06', 'Refunded', 'International'],
#  ['T0015', 'Webcam', '6', '518.01', 'Pending', 'South'],
# ...

# %%
Clean_Dataset[0]
# Out:
# ['T0001', 'Charger', '3', '1083.45', 'Completed', 'West']

# %%
for i in Clean_Dataset:
    # print(i)
    Quantity = int(i[2])
    # print(Quantity)
    UnitPrice = float(i[3])
    # print(UnitPrice)
    revenue = Quantity * UnitPrice
    i.append(round(revenue,2))

# %%
Clean_Dataset
# for i in Clean_Dataset:
#     i.pop(-1)
# Out:
# [['T0001', 'Charger', '3', '1083.45', 'Completed', 'West', 3250.35],
#  ['T0002', 'Charger', '2', '992.66', 'Cancelled', 'North', 1985.32],
#  ['T0003', 'Webcam', '3', '1144.62', 'Pending', 'South', 3433.86],
#  ['T0004', 'Mouse', '8', '43.76', 'Pending', 'International', 350.08],
#  ['T0005', 'Mouse', '2', '660.89', 'Pending', 'South', 1321.78],
#  ['T0006', 'Mouse', '8', '242.69', 'Completed', 'South', 1941.52],
#  ['T0007', 'Keyboard', '3', '507.11', 'Cancelled', 'International', 1521.33],
#  ['T0008', 'Charger', '9', '91.60', 'Completed', 'North', 824.4],
#  ['T0009', 'Monitor', '8', '236.28', 'Completed', 'South', 1890.24],
#  ['T0010', 'Laptop', '2', '304.67', 'Pending', 'International', 609.34],
#  ['T0011', 'Monitor', '7', '149.32', 'Cancelled', 'East', 1045.24],
#  ['T0012', 'Charger', '3', '603.68', 'Refunded', 'South', 1811.04],
#  ['T0013', 'Webcam', '3', '34.13', 'Pending', 'North', 102.39],
# ...

# %%
Dataset[0].index('CustomerRegion')
# Out:
# 5

# %%
Status =[]

for i in Clean_Dataset:
    # print(i[6])
    if i[4] == 'Completed':
        Status.append(i[6])

# %%
Status
# Out:
# [3250.35,
#  1941.52,
#  824.4,
#  1890.24,
#  2068.02,
#  5866.4,
#  2127.08,
#  1348.65,
#  5951.6,
#  4759.25,
#  2095.52,
#  3892.84,
#  2998.48,
#  5744.04,
#  4279.32,
#  1139.4,
#  1024.45,
#  1919.43,
#  4633.37,
#  7406.07,
#  4087.79,
#  197.41,
#  6376.38,
#  2902.74,
#  138.66,
#  1654.92]

# %%
sum(Status)
# Out:
# 80518.33

# %%
len(Status)
# Out:
# 26

# %%
marks =100

if marks >= 90 and marks <=100:
    print("A+")
# Out:
# A+
