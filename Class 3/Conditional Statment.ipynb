# %% [markdown]
# *   **Conditional Statements:** The syntax and structure of `if` and `else` statements, proper indentation (tab spaces), and how these conditions evaluate to boolean values (`True` or `False`).
# *   **Relational/Comparison Operators:** Using operators to build conditions, including greater than (`>`), less than (`<`), greater than or equal to (`>=`), less than or equal to (`<=`), equal to (`==`), and not equal to (`!=`).
# *   **Reading CSV Files:** How to open a file with `open()`, handle encoding like `utf-8`, import the `csv` library, and use the `csv.reader()` method.
# *   **Data Structures (List of Lists):** Converting the imported CSV data into a nested list format using the `list()` function to make it easier to analyze.
# *   **Loops and Iteration:** Using `for` loops (e.g., `for i in dataset`) to fetch and process data row by row.
# *   **Indexing and Slicing:** Finding specific item positions using `.index()` and slicing lists (e.g., `[1:]`) to separate headers from numerical data.
# *   **Typecasting:** Converting string values imported from the CSV file into integers or floats so they can be used for arithmetic operations.
# *   **List Manipulation Methods:** Using `.append()` to add new values (like extracted marks or calculated percentages) to lists, and using `.pop()` to remove elements.
# *   **Calculating Averages:** Finding the average of numeric data by combining the `sum()` function to add values and the `len()` function to count the number of values.

# %% [markdown]
# | Operator | Name | Example | Result (if x=5, y=3) | Description |
# | :--- | :--- | :--- | :--- | :--- |
# | `==` | Equal to | `x == y` | `False` | Checks if values are identical. |
# | `!=` | Not equal to | `x != y` | `True` | Checks if values are different. |
# | `>` | Greater than | `x > y` | `True` | Is left strictly larger than right? |
# | `<` | Less than | `x < y` | `False` | Is left strictly smaller than right? |
# | `>=` | Greater or equal | `x >= 5` | `True` | Is left larger OR equal to right? |
# | `<=` | Less or equal | `y <= 3` | `True` | Is left smaller OR equal to right? |

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ### Task 1: E-Commerce Sales Analysis

# %% [markdown]
# **Real-Life Scenario:** You are a data analyst for an online retail store. You have received a raw export of daily transactions. Your goal is to clean the data, calculate revenue per transaction, identify high-value customers, and determine shipping costs based on specific conditions.
#
#
# #### 2. Student Instructions
# 1.  **Read & Structure:** Open `sales_data.csv` using `csv.reader()`. Convert the reader object into a list of lists.
# 2.  **Clean Headers:** Use slicing (`[1:]`) to separate the header row from the data rows.
# 3.  **Typecasting & Calculation:**
#     *   Iterate through the data using a `for` loop.
#     *   Convert `Quantity` to `int` and `UnitPrice` to `float`.
#     *   Calculate `Total Revenue` = Quantity × UnitPrice.
#     *   Use `.append()` to add this calculated revenue to a new list called `revenues`.
# 4.  **Filtering:** Create a new list containing only the revenues where the `Status` is "Completed".
# 5.  **Analysis:** Calculate the average revenue of completed transactions using `sum()` and `len()`.

# %% [markdown]
# ### Task 2: Hospital Patient Triage System

# %% [markdown]
# **Real-Life Scenario:** You are working with a hospital database. You need to process patient vitals to categorize their urgency level, calculate Body Mass Index (BMI), and flag patients who require immediate attention based on multiple health indicators.
#
#
# #### 2. Student Instructions
# 1.  **Import & Parse:** Import the `csv` library, open the file with `utf-8` encoding, and load the data into a nested list.
# 2.  **Header Handling:** Use `.index()` to find the position of "Weight_kg" and "Height_cm" dynamically, then slice the list to exclude headers.
# 3.  **Data Processing:**
#     *   Loop through each patient row.
#     *   Typecast Weight to `float` and Height to `float` (convert cm to meters for BMI).
#     *   Calculate BMI = Weight / (Height_in_meters ** 2).
#     *   Append the calculated BMI to a `bmi_list`.
# 4.  **Statistical Output:** Calculate the average BMI of all patients.
#
#
# #### 3. 🌟 Bonus Challenge (Conditional Logic)
# **Scenario:** Implement a triage priority system. Create a list called `priority_flags`. Inside your loop, use nested `if-else` statements to assign a priority string ("LOW", "MEDIUM", "HIGH", "CRITICAL") based on:
# *   **CRITICAL:** If `Condition` is "Critical" OR (`HeartRate` > 110 AND `Temp_C` > 39.0).
# *   **HIGH:** If `Condition` is "Observation" AND (`BMI` < 18.5 OR `BMI` > 30.0).
# *   **MEDIUM:** If `Age` > 75 regardless of other factors (unless already Critical).
# *   **LOW:** All other cases.
# *   **Task:** Count how many patients fall into the "CRITICAL" or "HIGH" categories and print their Patient IDs.
#
# ---

# %% [markdown]
# ### Task 3: Renewable Energy Grid Monitoring

# %% [markdown]
# **Real-Life Scenario:** You are an engineer monitoring a solar farm. The system logs energy production every hour. You need to analyze efficiency, compare output against weather conditions, and identify underperforming panels that need maintenance.
#
#
# #### 2. Student Instructions
# 1.  **File Handling:** Open `solar_grid.csv` ensuring proper encoding. Read all rows into a list of lists.
# 2.  **Separation:** Slice the list to isolate data rows from the header.
# 3.  **Computation:**
#     *   Iterate through the rows.
#     *   Convert `Voltage` and `Current_Amps` to floats.
#     *   Calculate `Actual_Output` = Voltage × Current_Amps × 10 (scaling factor).
#     *   Convert `Expected_Output` to an integer.
#     *   Append `Actual_Output` values to a list.
# 4.  **Efficiency Check:** Create a list of differences: `Difference = Actual_Output - Expected_Output`.
# 5.  **Average:** Calculate the average `Actual_Output` across all logs.
#
# #### 3. 🌟 Bonus Challenge (Conditional Logic)
# **Scenario:** Determine the maintenance action required for each log entry. Create a list `maintenance_actions`. Use complex `if-elif-else` logic:
# *   **ACTION: REPLACE IMMEDIATELY** if `Actual_Output` is less than 20% of `Expected_Output` AND `Weather` is "Sunny" (indicates hardware failure despite good weather).
# *   **ACTION: CLEAN PANELS** if `Actual_Output` is between 20% and 50% of `Expected_Output` AND `Weather` is "Sunny".
# *   **ACTION: CHECK WIRING** if `Voltage` < 22.0 regardless of output.
# *   **ACTION: NORMAL** if `Actual_Output` >= `Expected_Output`.
# *   **ACTION: IGNORE** if `Weather` is "Rainy" (low output is expected).
# *   **Task:** Count the total number of "REPLACE IMMEDIATELY" and "CLEAN PANELS" actions required and list the unique `PanelType` IDs associated with these issues.
